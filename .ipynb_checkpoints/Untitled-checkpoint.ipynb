# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
init=pd.read_csv('pythonDS.csv',sep=';')

# %%
init
# Out:
#      Unnamed: 0             Name Alignment  Intelligence  Strength  Speed  \
# 0             1          3-D Man      good            50        31     43
# 1             2           A-Bomb      good            38       100     17
# 2             3       Abe Sapien      good            88        14     35
# 3             4         Abin Sur      good            50        90     53
# 4             5      Abomination       bad            63        80     53
# ..          ...              ...       ...           ...       ...    ...
# 597         598     Yellowjacket      good            88        10     12
# 598         599  Yellowjacket II      good            50        10     35
# 599         600             Ymir      good            50       100     27
# 600         601          Zatanna      good            75        10     23
# 601         602             Zoom       bad            50        10    100
#
#      Durability  Power  Combat  Total  pseudo_total  Total_check
# ...

# %%
second = init[['Intelligence','Strength','Speed','Durability','Power','Combat']]

# %%
second
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(second)


tsne_results[:,0]
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 602 samples in 0.001s...
# [t-SNE] Computed neighbors for 602 samples in 0.018s...
# [t-SNE] Computed conditional probabilities for sample 602 / 602
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.889599
# [t-SNE] KL divergence after 300 iterations: 0.678451
# array([-2.292599  , -2.1553185 , -6.4587035 ,  3.1078076 ,  0.8545644 ,
#         3.5899823 ,  3.2432964 , -1.1612831 , -1.1995449 , -0.3753093 ,
#         2.524653  ,  2.1049588 ,  2.4860456 ,  0.28996384, -4.014965  ,
#        -0.12497379,  4.0550914 , -0.9279738 ,  0.6007946 , -1.1461567 ,
#        -0.16350603, -1.7567649 ,  2.3124394 ,  2.3488014 , -2.649252  ,
#        -1.5596507 ,  4.8495493 , -0.5836096 ,  4.9439116 , -0.04758161,
#         6.26992   ,  1.2891169 , -1.611781  , -1.2379575 , -2.2122264 ,
#         0.11135334,  0.7711439 , -1.276876  , -2.0281458 ,  1.5176904 ,
# ...

# %%
second['tsne-one'] = tsne_results[:,0]
second['tsne-two'] = tsne_results[:,1]


plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-one", y="tsne-two",
    hue="y",
    palette=sns.color_palette("hls", 10),
    data=second,
    legend="full",
    alpha=0.3
)
# Out:
# <ipython-input-31-7953e683a605>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second['tsne-one'] = tsne_results[:,0]
# <ipython-input-31-7953e683a605>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second['tsne-two'] = tsne_results[:,1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-7953e683a605> in <module>
#       4
#       5 plt.figure(figsize=(16,10))
# ...

# %%
#tsne_results

# %%
#tsne_results.to_csv('hw5_Robj.csv')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-19-1b62eb81e459> in <module>
# ----> 1 s = pd.Series(tsne_results)
#       2 s.to_csv('hw5_Robj.csv')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
# ...
