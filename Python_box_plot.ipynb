# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import joypy as jp

# %%
init=pd.read_csv('derived_data/Overall.csv',encoding='latin1')

df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv", parse_dates=['date']).head(100)

df[1:20,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-dc1f95b5c20c> in <module>
#       3 df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv", parse_dates=['date']).head(100)
#       4
# ----> 5 df[1:20,1]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
# ...

# %%
initStart = init[init.StartMo1 >= 0]

# %%
for col in initStart.columns: 
    print(col)

#x = np.arange(initStart.StartMo1[0])
x=initStart.StartMo1
#x[1:]

df.head(40)
#x
#min(initStart.StartMo1)
# Out:
# WarNum
# WarName
# V5RegionNum
# WarType
# CcodeA
# SideA
# SideB
# Intnl
# StartMo1
# StartDy1
# StartYr1
# EndMo1
# EndDy1
# EndYr1
# StartMo2
# StartDy2
# StartYr2
# EndMo2
# EndDy2
# EndYr2
# StartMo3
# StartDy3
# StartYr3
# EndMo3
# EndDy3
# EndYr3
# StartMo4
# StartDy4
# StartYr4
# EndMo4
# EndDy4
# EndYr4
# WDuratDays
# WDuratMo
# TotNatMonWar
# TransFrom
# Initiator
# Outcome
# TransTo
# DeathsSideA
# DeathsSideB
# TotalBDeaths
# Version
# WarTypeC
# V5RegionC
# OutcomeC
# WarTypeD
# OutcomeD
# TotalBDeathsU
# Americas
# Phase1_st
# Phase2_st
# Phase3_st
# Phase4_st
# Phase1_en
# Phase2_en
# Phase3_en
# Phase4_en
# InitiatorDeaths
# RecipientDeaths
# InitiatorDeaths2
# RecipientDeaths2
# AbsDiffDeaths
# RelDiffDeaths
# StartYR_Norm
# InitiatorDeathsImp
# RecipientDeathsImp
# AbsDiffDeathsImp
# RelDiffDeathsImp
# OutcomeE
# cluster
#          date    pce     pop  psavert  uempmed  unemploy
# 0  1967-07-01  507.4  198712     12.5      4.5      2944
# ...

# %%
y_abs=initStart.RelDiffDeathsImp
max(y_abs)





#second = init[['Intelligence','Strength','Speed','Durability','Power','Combat']]
# Out:
# 0.5338675213675214

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.fill_between(x, y_abs, 1, where=y_abs >= 0, facecolor='green', interpolate=True, alpha=0.7)
plt.fill_between(x, y_abs, 1, where=y_abs <= 0, facecolor='red', interpolate=True, alpha=0.7)



#Decorating
#xtickvals = [str(m)[:3].upper()+"-"+str(y) for y,m in zip(df.date.dt.year, df.date.dt.month_name())]
#plt.gca().set_xticks(x[::6])
#plt.gca().set_xticklabels(xtickvals[::6], rotation=90, fontdict={'horizontalalignment': 'center', 'verticalalignment': 'center_baseline'})
plt.ylim(0,1)
plt.xlim(1,12)
plt.title("Seasonal absolute difference in war initiator deaths", fontsize=22)
plt.ylabel('Absolute difference in initiator deaths')
plt.xlabel('Start month of war')
plt.grid(alpha=0.5)
plt.show()


#second
#tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
#tsne_results = tsne.fit_transform(second)


#tsne_results[:,0]
# Out:
# /bin/sh: 1: pip: not found

# %%
pip install joypy

#plt.figure(figsize=(16,10), dpi= 80)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 1, "TotalBDeaths"], shade=True, color="g", label="Month 1", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 2, "TotalBDeaths"], shade=True, color="deeppink", label="Month 2", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 3, "TotalBDeaths"], shade=True, color="dodgerblue", label="Month 3", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 4, "TotalBDeaths"], shade=True, color="orange", label="Month 4", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 5, "TotalBDeaths"], shade=True, color="black", label="Month 5", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 6, "TotalBDeaths"], shade=True, color="red", label="Month 6", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 7, "TotalBDeaths"], shade=True, color="yellow", label="Month 7", alpha=.3)
#sns.kdeplot(initStart.loc[initStart['StartMo1'] == 8, "TotalBDeaths"], shade=True, color="purple", label="Month 8", alpha=.3)

plt.figure(figsize=(16,10), dpi= 80)
fig, axes = joypy.joyplot(AbsDiffDeathsImp, column=['WarTypeD'], by="StartMo1", ylim='own', figsize=(14,10))

# Decoration
plt.title('Joy Plot of War type and its absolute difference in initiator deaths by Starting Month', fontsize=22)
plt.legend()
plt.show()


# Decoration
#plt.title('Density Plot of Total deaths by Month', fontsize=22)
#plt.legend()
#plt.show()



#third = init[['Alignment','Intelligence','Strength','Speed','Durability','Power','Combat']]

#third['tsne-one'] = tsne_results[:,0]
#third['tsne-two'] = tsne_results[:,1]

#g =sns.scatterplot(x="tsne-one", y="tsne-two",            hue="Alignment",          data=third)
#g

#plt.savefig('Python_TSNE.png')
# Out:
#   File "<ipython-input-101-4dfb83d21eda>", line 1
#     pip install joypy
#         ^
# SyntaxError: invalid syntax

# %%
tsne_results[:,0]

# %%
third
third.to_csv('hw5_Robj.csv')
