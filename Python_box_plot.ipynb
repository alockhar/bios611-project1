# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import joypy as jp

# %%
init=pd.read_csv('derived_data/Overall.csv',encoding='latin1')

#df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv", parse_dates=['date']).head(100)

#df[1:20,1]

# %%
initStart = init[init.StartMo1 >= 0]

# %%
for col in initStart.columns: 
    print(col)

#x = np.arange(initStart.StartMo1[0])
x=initStart.StartMo1
#x[1:]


#x
min(initStart.AbsDiffDeathsImp)
tester = initStart[initStart.AbsDiffDeathsImp == -374775]
tester
# Out:
# WarNum
# WarName
# V5RegionNum
# WarType
# CcodeA
# SideA
# SideB
# Intnl
# StartMo1
# StartDy1
# StartYr1
# EndMo1
# EndDy1
# EndYr1
# StartMo2
# StartDy2
# StartYr2
# EndMo2
# EndDy2
# EndYr2
# StartMo3
# StartDy3
# StartYr3
# EndMo3
# EndDy3
# EndYr3
# StartMo4
# StartDy4
# StartYr4
# EndMo4
# EndDy4
# EndYr4
# WDuratDays
# WDuratMo
# TotNatMonWar
# TransFrom
# Initiator
# Outcome
# TransTo
# DeathsSideA
# DeathsSideB
# TotalBDeaths
# Version
# WarTypeC
# V5RegionC
# OutcomeC
# WarTypeD
# OutcomeD
# TotalBDeathsU
# Americas
# Phase1_st
# Phase2_st
# Phase3_st
# Phase4_st
# Phase1_en
# Phase2_en
# Phase3_en
# Phase4_en
# InitiatorDeaths
# RecipientDeaths
# InitiatorDeaths2
# RecipientDeaths2
# AbsDiffDeaths
# RelDiffDeaths
# StartYR_Norm
# InitiatorDeathsImp
# RecipientDeathsImp
# AbsDiffDeathsImp
# RelDiffDeathsImp
# OutcomeE
# cluster
#      WarNum                         WarName  V5RegionNum  WarType  CcodeA  \
# 174   677.0  Russian Civil War of 1917-1920            3        4     365
#
#       SideA            SideB  Intnl  StartMo1  StartDy1  ...  \
# 174  Russia  Anti-Bolsheviks      1        12         9  ...
#
#      RecipientDeaths2  AbsDiffDeaths RelDiffDeaths  StartYR_Norm  \
# 174          702000.0      -374775.0      0.533868            99
#
#      InitiatorDeathsImp  RecipientDeathsImp  AbsDiffDeathsImp  \
# 174              327225              702000           -374775
#
#      RelDiffDeathsImp  OutcomeE  cluster
# 174          0.533868     Other        3
#
# [1 rows x 71 columns]

# %%
y_abs=initStart.RelDiffDeathsImp
max(y_abs)





#second = init[['Intelligence','Strength','Speed','Durability','Power','Combat']]
# Out:
# 0.5338675213675214

# %%
# Out:
# /bin/sh: 1: pip: not found

# %%
plt.figure(figsize=(13,10), dpi= 80)
sns.violinplot(x='StartMo1', y='AbsDiffDeathsImp', data=initStart, scale='width', inner='quartile')

g=plt.annotate('Russian \nCivil War\n1917-1920', xy=(11, -440000), xytext=(12, -420000),
             bbox=dict(boxstyle='square', fc='firebrick'),
             arrowprops=dict(facecolor='steelblue', shrink=0.05), fontsize=15, color='white')

g
# Decoration
plt.title('Violin Plot of absolute difference in initiator deaths by war starting month', fontsize=22)
#plt.show()
plt.savefig('Python_proj_violin.png') 

# Decoration
#plt.title('Density Plot of Total deaths by Month', fontsize=22)
#plt.legend()
#plt.show()



#third = init[['Alignment','Intelligence','Strength','Speed','Durability','Power','Combat']]

#third['tsne-one'] = tsne_results[:,0]
#third['tsne-two'] = tsne_results[:,1]

#g =sns.scatterplot(x="tsne-one", y="tsne-two",            hue="Alignment",          data=third)
#g

#plt.savefig('Python_TSNE.png')

# %%
tsne_results[:,0]

# %%
third
third.to_csv('hw5_Robj.csv')
